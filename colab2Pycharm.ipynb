# %% [markdown]
# <a href="https://colab.research.google.com/github/sw6820/colab2pycharm/blob/main/colab2Pycharm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# colab에서 사용할 GPU 할당

# %% [markdown]
# ![스크린샷 2022-09-16 20.38.37.png](data:image/png;base64,...)

# %% [markdown]
# ![스크린샷 2022-09-16 20.43.30.png](data:image/png;base64,...)

# %% [markdown]
# 사용될 GPU 확인

# %%
# !nvidia-smi
# Out:
# Fri Sep 16 11:58:03 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   57C    P8    11W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# https://dashboard.ngrok.com/get-started/setup
# 에서 토큰 생성

# %% [markdown]
# ![스크린샷 2022-09-16 20.48.22.png](data:image/png;base64,...)

# %% [markdown]
# $ ngrok config add-authtoken [token]
#
# [token] 부분의 토큰을 복사해서 아래에 입력

# %%
# https://dashboard.ngrok.com/get-started/setup 
# 에서 생성한 토큰번호
NGROK_TOKEN = '25Xb0UMa8rvW49yZILMgztm47vd_7x6ZGH1PFkNs2KSHh5HpJ' # $ ngrok config add-authtoken [token]
PASSWORD = '1234' # 원하는 임의의 비밀번호 설정(파이참에서 접속 시 사용)

# %%
# !pip install colab-ssh
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# www.jetbrains.com/ko-kr/community/education/#students
# 에서 학생용 메일이 있으면 professional version 사용 가능
#
# 해당 기능은 professional version에서만 사용 가능

# %%
from colab_ssh import launch_ssh
launch_ssh(NGROK_TOKEN,PASSWORD)
# professional 학생용 1년 무료
# www.jetbrains.com/ko-kr/community/education/#students

#Pycharm에서 안되면 여러번 해본다.
# Out:
# ...
# we highly recommend that update your code by following this documentation https://github.com/WassimBenzarti/colab-ssh#getting-started
# Successfully running 0.tcp.ngrok.io:14163
# [Optional] You can also connect with VSCode SSH Remote extension using this configuration:
#
#   Host google_colab_ssh
#     HostName 0.tcp.ngrok.io
#     User root
#     Port 14163

# %% [markdown]
# PyCharm > Preferences

# %% [markdown]
# ![스크린샷 2022-09-16 20.52.20.png](data:image/png;base64,...)

# %% [markdown]
# Project: [project_name] > Python Interpreter > Add Interpreter > On SSH...
#
# Path mappings: Google drive 내에서 코드를 저장할 경로(파이참에서 생성한 코드가 자동 deployment),
#
# path mapping default : /tmp 이하 경로에 임시저장

# %% [markdown]
# ![스크린샷 2022-09-16 20.56.37.png](data:image/png;base64,...)

# %% [markdown]
# ![스크린샷 2022-09-16 21.00.55.png](data:image/png;base64,...)

# %% [markdown]
# ![스크린샷 2022-09-16 21.00.14.png](data:image/png;base64,...)

# %% [markdown]
# 위에서 실행한 셀에서 나온
#
# HostName -> Host
#
# User -> Username
#
# Port -> Port에 입력
#
# OK입력

# %% [markdown]
# ![스크린샷 2022-09-16 21.02.49.png](data:image/png;base64,...)

# %% [markdown]
# 위에서 지정한 비밀번호 입력

# %% [markdown]
# ![스크린샷 2022-09-16 21.11.49.png](data:image/png;base64,...)

# %% [markdown]
# ![스크린샷 2022-09-16 21.10.56.png](data:image/png;base64,...)
